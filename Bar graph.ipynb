# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadalfateh6/Skin-lesion-Classification-Deep-learning/blob/main/Bar%20graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
values = [47129 , 10015 ]
labels = ['Benign', 'Malignant']
colorss=[ 'green', 'red']
x = np.arange(len(labels))
plt.bar(x, values, color=colorss, width=0.5)
plt.xticks(x, labels)
plt.ylabel('Number Of Images')
plt.title('Class Distribution In ISIC2018 Dataset')
# Out:
# Text(0.5, 1.0, 'Class Distribution In ISIC2018 Dataset')
